# %% [markdown]
# <a href="https://colab.research.google.com/github/CaBlaze/Quimicag3/blob/main/Gases_parte_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Generar datos usando drawdata para obtener:
# (a) Ley de Boyle
# (b) Ley de Charles
# (c) Ley de Gay Lussac
# (d) Velocidad vs Número de moléculas
# Puede utilizar excel (u otro) para obtener el ajuste de recta

# %%
# instalamos:
# %%capture
# !pip install drawdata

# %%
# Importamos
from drawdata import draw_scatter, draw_histogram, draw_line
draw_scatter()
#Dibujamos
#Ley de Boyle
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("data.csv")
df
#Sirve para hacer la tabla del dibujo
# Out:
#               x           y  z
# 0     73.236803  474.429361  a
# 1     94.265522  465.855612  a
# 2     61.410348  481.567569  a
# 3     82.567629  477.228133  a
# 4     89.997903  490.588705  a
# ..          ...         ... ..
# 266  128.579278  363.215102  a
# 267  103.002198  425.796422  a
# 268  124.942194  373.301289  a
# 269  149.212853  363.067814  a
# 270  132.377452  370.855767  a
#
# [271 rows x 3 columns]

# %%
df["y"]=1/df["y"]
plt.scatter(df["x"],df["y"])
#Grafica con los datos estadisticos del dibujo

# %% [markdown]
# Ley de Boyle con Excel:

# %% [markdown]
# ![boyle.PNG](data:image/png;base64,...)

# %%
# Importamos
from drawdata import draw_scatter, draw_histogram, draw_line
draw_scatter()
#Dibujamos
#Ley de Charles
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("Charles.csv")
df
#Sirve para hacer la tabla del dibujo
# Out:
#               x           y  z
# 0    131.597361  390.185256  a
# 1    136.900080  411.617249  a
# 2    122.474465  431.701933  a
# 3     81.091325  425.814168  a
# 4    115.910968  378.368734  a
# ..          ...         ... ..
# 404  446.439014  229.485324  a
# 405  419.715782  236.979155  a
# 406  439.480143  246.978762  a
# 407  487.544482  246.837667  a
# 408  461.358543  329.326774  a
#
# [409 rows x 3 columns]

# %%
plt.scatter(df["x"],df["y"])

# %% [markdown]
# Ley de Charles con Excel

# %% [markdown]
# ![charles.PNG](data:image/png;base64,...)

# %%
# Importamos
from drawdata import draw_scatter, draw_histogram, draw_line
draw_scatter()
#Dibujamos
#Gay Lussac
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("gussac.csv")
df
#Sirve para hacer la tabla del dibujo
# Out:
#               x           y  z
# 0    119.426482  425.734674  a
# 1    146.275833  428.749573  a
# 2    199.783317  398.329459  a
# 3    149.871471  408.110830  a
# 4    185.351605  409.583555  a
# ..          ...         ... ..
# 181  230.533736  450.708889  a
# 182  247.470119  432.204513  a
# 183  197.573657  427.772281  a
# 184  243.068332  469.344944  a
# 185  186.171540  462.255590  a
#
# [186 rows x 3 columns]

# %%
plt.scatter(df["x"],df["y"])

# %% [markdown]
# Ley de Gay Lussac con Excel

# %% [markdown]
# ![gussac.PNG](data:image/png;base64,...)

# %% [markdown]
# (d) Velocidad vs Número de moléculas

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("histo.csv")
df
#Sirve para hacer la tabla del dibujo
# Out:
#          x       y  z
# 0    0.000  0.0000  a
# 1    0.025  0.0492  a
# 2    0.050  0.0892  a
# 3    0.075  0.1192  a
# 4    0.100  0.1452  a
# ..     ...     ... ..
# 115  0.875  0.1072  c
# 116  0.900  0.0772  c
# 117  0.925  0.0372  c
# 118  0.950  0.0372  c
# 119  0.975  0.0000  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(df["x"],df["y"])

# %%
dfa = df[df["z"]=="a"]
print("Medidas de tendencia para el gráfico A")
print(dfa["y"].describe(),"\n")

dfb = df[df["z"]=="b"]
print("Medidas de tendencia para el gráfico B")
print(dfb["y"].describe(),"\n")

dfc = df[df["z"]=="c"]
print("Medidas de tendencia para el gráfico C")
print(dfc["y"].describe())
# Out:
# Medidas de tendencia para el gráfico A
# count    40.000000
# mean      0.130610
# std       0.082592
# min       0.000000
# 25%       0.085200
# 50%       0.141200
# 75%       0.203700
# max       0.235200
# Name: y, dtype: float64
#
# Medidas de tendencia para el gráfico B
# count    40.000000
# mean      0.307420
# std       0.318641
# min       0.000000
# 25%       0.040700
# 50%       0.148200
# 75%       0.615200
# max       0.847200
# Name: y, dtype: float64
#
# Medidas de tendencia para el gráfico C
# count    40.000000
# mean      0.285240
# std       0.151254
# min       0.000000
# 25%       0.186700
# 50%       0.300200
# 75%       0.440200
# max       0.469200
# Name: y, dtype: float64

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_greenhouse_gas_emissions'
tablas = pd.read_html(url)

# %%
tablas[1]
# Out:
#                                                  State  \
# 0                                                World
# 1       China (see: Greenhouse gas emissions by China)
# 2    United States (see: Greenhouse gas emissions b...
# 3       India (see: Greenhouse gas emissions by India)
# 4    European Union (EU28, including the United Kin...
# ..                                                 ...
# 190                                           Kiribati
# 191                                       Cook Islands
# 192                                              Nauru
# 193                                             Tuvalu
# 194                                               Niue
#
#      Production-based emissions (MtCO2e) 2018 (CAIT)[1]  \
# 0                                             48928.00
# 1                                             11706.00
# 2                                              5794.00
# 3                                              3347.00
# ...

# %%
plt.figure(figsize=(70,30))
plt.xticks(rotation=90)
tablas[1]['Production-based emissions (MtCO2e) 2018 (CAIT)[1]']=tablas[1]['Production-based emissions (MtCO2e) 2018 (CAIT)[1]'].drop(0)
tablas[1]['State'] = tablas[1]['State'].drop(0)
tablas[1]['State'] = tablas[1]['State'].astype(str)
plt.bar(tablas[1]['State'],tablas[1]['Production-based emissions (MtCO2e) 2018 (CAIT)[1]'])
# Out:
# <BarContainer object of 195 artists>
